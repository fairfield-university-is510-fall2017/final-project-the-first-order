# %% [markdown]
# # NFL Analysis

# %% [markdown]
# #### Import Packages

# %%
import sqlite3
import pandas as pd
import sqlalchemy 
import matplotlib.pyplot as plt
import seaborn as sb
# %load_ext sql

# %sql sqlite:///football.db
# Out:
# 'Connected: None@football.db'

# %%
# %sql sqlite:///football.db
# Out:
# 'Connected: None@football.db'

# %% [markdown]
# ### Import 2016 Team Data for Merge

# %%
#Reading in our hosted CSV file
team_2016=pd.read_csv("Team_2016_data.csv",header=0,sep=';',names=['TM','Games','Points_Scored','Yards_Gained','Num_Plays','Yards_per_Play','Turnovers_Lost','Fumbles_Lost','First_Down'])

#Checking the output is what we expect
print(team_2016.head())
print(team_2016.dtypes)
# Out:
#                      TM  Games  Points_Scored  Yards_Gained  Num_Plays  \
# 0       Atlanta Falcons     16            540          6653        995
# 1    New Orleans Saints     16            469          6816       1105
# 2  New England Patriots     16            441          6180       1056
# 3     Green Bay Packers     16            432          5900       1029
# 4        Dallas Cowboys     16            421          6027       1010
#
#    Yards_per_Play  Turnovers_Lost  Fumbles_Lost  First_Down
# 0             6.7              11             4         379
# 1             6.2              24             9         395
# 2             5.9              11             9         351
# 3             5.7              17             9         349
# 4             6.0              15             9         358
# TM                 object
# Games               int64
# Points_Scored       int64
# Yards_Gained        int64
# Num_Plays           int64
# Yards_per_Play    float64
# Turnovers_Lost      int64
# Fumbles_Lost        int64
# First_Down          int64
# dtype: object

# %% [markdown]
# ### Convert DataFrame to SQL Table

# %% [markdown]
# we created an empty table to insert our data into

# %%
# %%sql
# drop table if exists TeamStats2016;
# CREATE TABLE TeamStats2016(
#     TM TEXT Not Null,
#     Games INTEGER default NULL,
#     Points_Scored INTEGER default NULL,
#     Yards_Gained INTEGER default NULL,
#     Num_Plays INTEGER default NULL,
#     Yards_per_Play INTEGER default NULL,
#     Turnovers_Lost INTEGER default NULL,
#     Fumbles_Lost INTEGER default NULL,
#     First_Down INTEGER default NULL
# );
# Out:
# 0 rows affected.
# 0 rows affected.
# []

# %%
#Creating a variable to conenct to database
conn = sqlite3.connect('football.db')

#Converting our dataframe and sending to SQL
team_2016.to_sql('TeamStats2016',conn,if_exists='append',index=False)

# %% [markdown]
# Displaying the table to check for errors

# %%
# %%sql
# SELECT *
# FROM TeamStats2016;
# Out:
# Done.
# [('Atlanta Falcons', 16, 540, 6653, 995, 6.7, 11, 4, 379),
#  ('New Orleans Saints', 16, 469, 6816, 1105, 6.2, 24, 9, 395),
#  ('New England Patriots', 16, 441, 6180, 1056, 5.9, 11, 9, 351),
#  ('Green Bay Packers', 16, 432, 5900, 1029, 5.7, 17, 9, 349),
#  ('Dallas Cowboys', 16, 421, 6027, 1010, 6, 15, 9, 358),
#  ('Arizona Cardinals', 16, 418, 5868, 1086, 5.4, 28, 11, 368),
#  ('Oakland Raiders', 16, 416, 5973, 1048, 5.7, 14, 7, 333),
#  ('Indianapolis Colts', 16, 411, 5830, 1037, 5.6, 22, 7, 351),
#  ('Los Angeles Chargers', 16, 410, 5708, 1014, 5.6, 35, 14, 340),
#  ('Pittsburgh Steelers', 16, 399, 5962, 1026, 5.8, 18, 3, 336),
#  ('Buffalo Bills', 16, 399, 5666, 1012, 5.6, 12, 5, 328),
#  ('Washington Redskins', 16, 396, 6454, 1009, 6.4, 21, 9, 345),
#  ('Kansas City Chiefs', 16, 389, 5488, 990, 5.5, 17, 9, 305),
#  ('Tennessee Titans', 16, 381, 5728, 1008, 5.7, 18, 7, 322),
#  ('Carolina Panthers', 16, 369, 5499, 1052, 5.2, 29, 10, 318),
#  ('Philadelphia Eagles', 16, 367, 5398, 1080, 5, 20, 6, 333),
#  ('Miami Dolphins', 16, 363, 5324, 913, 5.8, 23, 8, 278),
#  ('Seattle Seahawks', 16, 354, 5715, 1012, 5.6, 18, 6, 313),
#  ('Tampa Bay Buccaneers', 16, 354, 5542, 1066, 5.2, 27, 9, 340),
#  ('Detroit Lions', 16, 346, 5421, 981, 5.5, 15, 5, 329),
#  ('Baltimore Ravens', 16, 343, 5563, 1079, 5.2, 23, 7, 316),
#  ('Denver Broncos', 16, 333, 5169, 1020, 5.1, 25, 14, 290),
#  ('Minnesota Vikings', 16, 327, 5041, 1006, 5, 16, 11, 303),
#  ('Cincinnati Bengals', 16, 325, 5711, 1050, 5.4, 17, 9, 341),
#  ('Jacksonville Jaguars', 16, 318, 5359, 1052, 5.1, 29, 13, 321),
#  ('New York Giants', 16, 310, 5291, 1018, 5.2, 27, 11, 289),
#  ('San Francisco 49ers', 16, 309, 4930, 996, 4.9, 25, 15, 287),
#  ('Chicago Bears', 16, 279, 5704, 967, 5.9, 31, 12, 324),
#  ('Houston Texans', 16, 279, 5035, 1071, 4.7, 24, 8, 305),
#  ('New York Jets', 16, 275, 5268, 1003, 5.3, 34, 9, 291),
#  ('Cleveland Browns', 16, 264, 4976, 983, 5.1, 25, 11, 296),
#  ('Los Angeles Rams', 16, 224, 4203, 960, 4.4, 29, 9, 245)]

# %% [markdown]
# Creating Merged table that hosts everything we need for analysis

# %%
# %%sql
# drop table if exists Teams_Merge;
# CREATE TABLE Teams_Merge AS
# SELECT  TID,
#         TeamName,
#         Conference,
#         Division,
#         T.SCORE as Score_week_1,
#         T.Total_Yards as Total_Yards_W1,
#         T.Turn_Overs as Turn_Overs_W1,
#         T.First_Downs as First_Downs_W1,
#         T16.Games as Games_2016,
#         T16.Points_Scored as Points_Scored_2016,
#         T16.Yards_Gained as Yards_Gained_2016,
#         T16.Num_Plays as Num_plays_2016,
#         T16.Yards_per_Play as Yards_per_Play_2016,
#         T16.Turnovers_Lost as Turnovers_Lost_2016,
#         T16.Fumbles_Lost as Fumbles_Lost_2016,
#         T16.First_Down as First_Down_2016
# FROM Teams
# JOIN TeamStats2016 T16 on TeamName = TM
# JOIN GAMESTATISTICS T on TID = TeamID
# ;
# Out:
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# Checking output

# %%
# %%sql
# SELECT * FROM Teams_Merge
# Out:
# Done.
# [(25, 'Denver Broncos', 'AFC', 'West', 21, 307, 3, 21, 16, 333, 5169, 1020, 5.1, 25, 14, 290),
#  (22, 'Carolina Panthers', 'NFC', 'South', 20, 333, 1, 21, 16, 369, 5499, 1052, 5.2, 29, 10, 318),
#  (21, 'Atlanta Falcons', 'NFC', 'South', 24, 374, 0, 19, 16, 540, 6653, 995, 6.7, 11, 4, 379),
#  (24, 'Tampa Bay Buccaneers', 'NFC', 'South', 31, 371, 1, 20, 16, 354, 5542, 1066, 5.2, 27, 9, 340),
#  (4, 'New York Jets', 'AFC', 'East', 31, 340, 1, 22, 16, 275, 5268, 1003, 5.3, 34, 9, 291),
#  (10, 'Cincinnati Bengals', 'AFC', 'North', 31, 381, 1, 18, 16, 325, 5711, 1050, 5.4, 17, 9, 341),
#  (23, 'New Orleans Saints', 'NFC', 'South', 34, 507, 1, 27, 16, 469, 6816, 1105, 6.2, 24, 9, 395),
#  (28, 'Oakland Raiders', 'AFC', 'West', 35, 486, 0, 25, 16, 416, 5973, 1048, 5.7, 14, 7, 333),
#  (26, 'Kansas City Chiefs', 'AFC', 'West', 33, 413, 1, 26, 16, 389, 5488, 990, 5.5, 17, 9, 305),
#  (27, 'Los Angeles Chargers', 'AFC', 'West', 27, 388, 0, 25, 16, 410, 5708, 1014, 5.6, 35, 14, 340),
#  (20, 'Tennessee Titans', 'AFC', 'South', 16, 316, 3, 19, 16, 381, 5728, 1008, 5.7, 18, 7, 322),
#  (16, 'Minnesota Vikings', 'NFC', 'North', 25, 301, 0, 15, 16, 327, 5041, 1006, 5, 16, 11, 303),
#  (7, 'Philadelphia Eagles', 'NFC', 'East', 29, 403, 0, 23, 16, 367, 5398, 1080, 5, 20, 6, 333),
#  (11, 'Cleveland Browns', 'AFC', 'North', 10, 288, 1, 14, 16, 264, 4976, 983, 5.1, 25, 11, 296),
#  (19, 'Jacksonville Jaguars', 'AFC', 'South', 23, 348, 1, 18, 16, 318, 5359, 1052, 5.1, 29, 13, 321),
#  (15, 'Green Bay Packers', 'NFC', 'North', 27, 294, 0, 20, 16, 432, 5900, 1029, 5.7, 17, 9, 349),
#  (9, 'Baltimore Ravens', 'AFC', 'North', 13, 308, 1, 18, 16, 343, 5563, 1079, 5.2, 23, 7, 316),
#  (1, 'Buffalo Bills', 'AFC', 'East', 7, 160, 0, 11, 16, 399, 5666, 1012, 5.6, 12, 5, 328),
#  (17, 'Houston Texans', 'AFC', 'South', 23, 344, 1, 17, 16, 279, 5035, 1071, 4.7, 24, 8, 305),
#  (13, 'Chicago Bears', 'NFC', 'North', 14, 258, 1, 14, 16, 279, 5704, 967, 5.9, 31, 12, 324),
#  (32, 'Seattle Seahawks', 'NFC', 'West', 12, 352, 2, 21, 16, 354, 5715, 1012, 5.6, 18, 6, 313),
#  (2, 'Miami Dolphins', 'AFC', 'East', 10, 214, 0, 11, 16, 363, 5324, 913, 5.8, 23, 8, 278),
#  (5, 'Dallas Cowboys', 'NFC', 'East', 19, 328, 0, 24, 16, 421, 6027, 1010, 6, 15, 9, 358),
#  (6, 'New York Giants', 'NFC', 'East', 20, 316, 1, 18, 16, 310, 5291, 1018, 5.2, 27, 11, 289),
#  (18, 'Indianapolis Colts', 'AFC', 'South', 35, 450, 0, 25, 16, 411, 5830, 1037, 5.6, 22, 7, 351),
#  (14, 'Detroit Lions', 'NFC', 'North', 39, 448, 0, 28, 16, 346, 5421, 981, 5.5, 15, 5, 329),
#  (29, 'Arizona Cardinals', 'NFC', 'West', 21, 344, 0, 21, 16, 418, 5868, 1086, 5.4, 28, 11, 368),
#  (3, 'New England Patriots', 'AFC', 'East', 23, 363, 2, 19, 16, 441, 6180, 1056, 5.9, 11, 9, 351),
#  (8, 'Washington Redskins', 'NFC', 'East', 16, 385, 2, 18, 16, 396, 6454, 1009, 6.4, 21, 9, 345),
#  (12, 'Pittsburgh Steelers', 'AFC', 'North', 38, 437, 1, 23, 16, 399, 5962, 1026, 5.8, 18, 3, 336),
#  (31, 'San Francisco 49ers', 'NFC', 'West', 28, 320, 1, 10, 16, 309, 4930, 996, 4.9, 25, 15, 287),
#  (30, 'Los Angeles Rams', 'NFC', 'West', 0, 185, 2, 28, 16, 224, 4203, 960, 4.4, 29, 9, 245)]

# %%
# Taking the new Teams Table out of SQL
mteams_2016_rs=%sql select * from Teams_Merge
mteams_2016 = mteams_2016_rs.DataFrame()
# Out:
# Done.

# %%
# Checking output
print(mteams_2016.head())
print(mteams_2016.dtypes)
# Out:
#    TID              TeamName Conference Division  Score_week_1  \
# 0   25        Denver Broncos        AFC     West            21
# 1   22     Carolina Panthers        NFC    South            20
# 2   21       Atlanta Falcons        NFC    South            24
# 3   24  Tampa Bay Buccaneers        NFC    South            31
# 4    4         New York Jets        AFC     East            31
#
#    Total_Yards_W1  Turn_Overs_W1  First_Downs_W1  Games_2016  \
# 0             307              3              21          16
# 1             333              1              21          16
# 2             374              0              19          16
# 3             371              1              20          16
# 4             340              1              22          16
#
#    Points_Scored_2016  Yards_Gained_2016  Num_plays_2016  Yards_per_Play_2016  \
# 0                 333               5169            1020                  5.1
# 1                 369               5499            1052                  5.2
# 2                 540               6653             995                  6.7
# 3                 354               5542            1066                  5.2
# 4                 275               5268            1003                  5.3
#
#    Turnovers_Lost_2016  Fumbles_Lost_2016  First_Down_2016
# 0                   25                 14              290
# 1                   29                 10              318
# 2                   11                  4              379
# 3                   27                  9              340
# 4                   34                  9              291
# TID                      int64
# TeamName                object
# Conference              object
# Division                object
# Score_week_1             int64
# Total_Yards_W1           int64
# Turn_Overs_W1            int64
# First_Downs_W1           int64
# Games_2016               int64
# Points_Scored_2016       int64
# Yards_Gained_2016        int64
# Num_plays_2016           int64
# Yards_per_Play_2016    float64
# Turnovers_Lost_2016      int64
# Fumbles_Lost_2016        int64
# First_Down_2016          int64
# dtype: object

# %% [markdown]
# ### Plotting Average Yards per Play by Team

# %%
# Creating plot to show average yard per play
f, (ax1) = plt.subplots(1, 1, figsize=(8, 6), sharex=True)
mteams_2016['Average_Yards_per_Play'] = mteams_2016.Yards_Gained_2016/mteams_2016.Num_plays_2016

x = mteams_2016['TeamName'].values
y1 = mteams_2016['Average_Yards_per_Play'].values
sb.barplot(x, y1,ax=ax1)
plt.xticks(rotation=90)
plt.savefig('Avg_Yards_Per_Play.png')

plt.show()

# %% [markdown]
# As we can see, Atlanta Falcons have the highest yard gainage per play in the 2016 season, followed by New England Patriots. Neither the Eagles or the Steelers made the top three.

# %% [markdown]
# ### Plotting Total 2016 Turnovers by Team

# %%
# Creating plot to show total turnovers per team
f, (ax1) = plt.subplots(1, 1, figsize=(8, 6), sharex=True)

x = mteams_2016['TeamName'].values
y1 = mteams_2016['Turnovers_Lost_2016'].values
sb.barplot(x, y1,ax=ax1)
plt.xticks(rotation=90)
plt.savefig('Total_Turnovers_by_Team.png')

plt.show()

# %% [markdown]
# The **Los Angeles Chargers** had the *greatest* number of turnovers in 2016, followed by the **New York Jets**. The **Atlanta Falcons** and **New England Patriots** were tied for *least* number of turnovers in the 2016 season.

# %% [markdown]
# ### Plotting Average Points Scored by Division and Conference

# %%
# Creating plot to show Average Points Scored per Division for each Conference
f, (ax1) = plt.subplots(1, 1, figsize=(8, 6), sharex=True)
sb.barplot(x="Conference", y="Points_Scored_2016", ax = ax1, hue="Division", data=mteams_2016,palette="Reds_d")
plt.savefig('Avg_Points_Scored_by_Division_and_Conf.png')
plt.show()

# %% [markdown]
# While the **West Division** leads the **AFC Conference** in average points scored for the 2016 season, the **South Division** leads the **NFC Conference**.

# %% [markdown]
# ### Plotting Average Total Week 1 Yards by Division and Conference

# %%
# Creating plot to show Average Total Yards in each Division for each Conference for Week 1 2016
f, (ax1) = plt.subplots(1, 1, figsize=(8, 6), sharex=True)
sb.barplot(x="Conference", y="Total_Yards_W1", ax = ax1, hue="Division", data=mteams_2016,palette="Blues_d")
plt.savefig('Avg_Total_W1_Yards_by_Division_and_Conf.png')
plt.show()

# %% [markdown]
# The same Divisions in each conference lead in terms of average yards gained in week one as did in average points scored for the total season. (With **West** Leading in the **AFC**, and **South** Leading in the **NFC**.)

# %% [markdown]
# ### Plotting Total Week 1 Yards Per Team

# %%
# Creating plot to show total yards  per team during week 1 of the 2016 season
f, (ax1) = plt.subplots(1, 1, figsize=(8, 6), sharex=True)

x = mteams_2016['TeamName'].values
y1 = mteams_2016['Total_Yards_W1'].values
sb.barplot(x, y1,ax=ax1)
plt.xticks(rotation=90)
plt.savefig('Avg_Total_W1_Yards_Per_Team.png')

plt.show()

# %% [markdown]
# During the first week of the 2016 season, **New Orleans Saints** gained the greatest number of yards.
